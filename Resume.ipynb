# %%
# Text Variables
Header = '...Resume created using Python.The code is in my github profile'
Name = 'SURANJANA KAJLI'
Title = 'Data Science & Analytics'
ContactHead = 'Contact Details'
Contact = 'suranjana443@gmail.com\n9431126009\ngithub.com/Suranjana-Kajli'

Objective = 'SUMMARY'
ObjectiveOne = 'Aspiring Data Scientist eager to analyse large datasets to discover trends/patterns\nProficient in Machine learning techniques & Predictive modelling\nWell-equipped with advanced SQL,Python,Python libraries & Data visualization\nIntrigued to learn everyday about new developments in Data science,ML,AI'
ProjectsHeader = 'PROJECTS/PUBLICATIONS'
Project1Title = 'Breast Cancer Prediction Model'
Project1Desc = '• Built a Logistic regression model to classify cancer as Malignant or Benign\n• Analysed/visualized/mined data using pandas/matplotlib/scikit-learn in Python\n• Used the Breast Cancer Wisconsin (Diagnostic) Data Set from Kaggle'
Project2Title = 'Credit Card Fraud Detection Model'
Project2Desc = '• Built a predictive model using Isolation Forest Algorithm\n• Also used Local Outlier Factor Algorithm & Support Vector Machines\n• Compared which of these algorithms performed best on the data'
Project3Title = 'Houses Price Prediction end to end model'
Project3Desc = '• Collected,cleaned,analysed data from scratch\n• Used pandas,matplotlib,scikit-learn to find out feature correlation\n• Model to predict house prices-tested on linear/logistic/random forest regression'
Project4Title = 'Artificial Intelligence Messenger chatbot'
Project4Desc = '• Built a chatbot & deployed it by integrating with Facebook Messenger\n• The chatbot converses with the customers & generates a booking\n• Explored intent,entities & dialog to create a conversational AI'

EduHeader = 'EDUCATION'
Certificate1 = 'IBM Data Analyst Professional Certificate'
Course1 = 'Coursera'
Certificate2 = 'Machine Learning by Stanford University,Andrew Ng'
Course2 = 'Coursera'
PostGraduation = 'Himalayan Garhwal University, M.Sc Mathematics'
PostGraduationM = 'CGPA-7.3'
Graduation = 'Delhi University, B.Sc(HONORS)Mathematics'
GraduationM = 'CGPA-8.4'
ISC = 'De-Nobili C.M.R.I,Class 12th(ISC)'
ISCM = 'CGPA-9.5'
ICSE = 'De-Nobili C.M.R.I,Class 10th(ICSE)'
ICSEM ='CGPA-9.9'

SkillsHeader = 'Skills'
SkillsDesc = '• Python\n• Python Libraries-(pandas,numpy,\n   scipy,scikit-learn,seaborn,\n   matplotlib,Beautifulsoup\n• Tableau \n• Advanced SQL\n• Machine Learning\n• Artificial Intelligence\n• Django\n• Cognos Analytics\n• Data Cleaning\n• Data Analysing\n• Data Wrangling\n• Data Visualization\n• Data Manipulation \n• Mathematics \n• Statistics/Statistical methods\n• Strong Communication skills\n• Advanced Excel'
Interests = 'Interests'
InterestsDesc = 'General Awareness, Quizzes, \nYoga, Painting, Dancing, \nSinging, Cooking, Travelling'
CodeTitle = 'Scan QRCode'

# Setting style for bar graphs
import matplotlib.pyplot as plt

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(8.5, 11))

# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#ffffff', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#01153E', alpha=1, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=2)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
plt.annotate(Header, (.02,.98), weight='regular', fontsize=8, alpha=.8)
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20, color='#01153E')
plt.annotate(Title, (.02,.91), weight='bold', fontsize=14, color='#01153E')
plt.annotate(ContactHead, (.7,.96), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(Contact, (.7,.906), weight='regular', fontsize=8, color='#ffffff')
plt.annotate(Objective, (.02,.86), weight='bold', fontsize=10, color='#01153E')
plt.annotate(ObjectiveOne, (.04,.79), weight='regular', fontsize=9)
plt.annotate(ProjectsHeader, (.02,.74), weight='bold', fontsize=10, color='#01153E')
plt.annotate(Project1Title, (.02,.72), weight='bold', fontsize=10)
plt.annotate(Project1Desc, (.04,.67), weight='regular', fontsize=9)
plt.annotate(Project2Title, (.02,.64), weight='bold', fontsize=10)
plt.annotate(Project2Desc, (.04,.59), weight='regular', fontsize=9)
plt.annotate(Project3Title, (.02,.56), weight='bold', fontsize=10)
plt.annotate(Project3Desc, (.04,.51), weight='regular', fontsize=9)
plt.annotate(Project4Title, (.02,.48), weight='bold', fontsize=10)
plt.annotate(Project4Desc, (.04,.43), weight='regular', fontsize=9)
plt.annotate(EduHeader, (.02,.38), weight='bold', fontsize=10, color='#01153E')
plt.annotate(Certificate1, (.02,.34), weight='bold', fontsize=10)
plt.annotate(Course1, (.02,.325), weight='regular', fontsize=9, alpha=.8)
plt.annotate(Certificate2, (.02,.28), weight='bold', fontsize=10)
plt.annotate(Course2, (.02,.265), weight='regular', fontsize=9, alpha=.8)
plt.annotate(PostGraduation, (.02,.220), weight='bold', fontsize=10, alpha=.8)
plt.annotate(PostGraduationM, (.02,.205), weight='regular', fontsize=9, alpha=.8)
plt.annotate(Graduation, (.02,.160), weight='bold', fontsize=10)
plt.annotate(GraduationM, (.02,.145), weight='regular', fontsize=9, alpha=.8)
plt.annotate(ISC, (.02,.105), weight='bold', fontsize=10)
plt.annotate(ISCM, (.02,.090), weight='regular', fontsize=9, alpha=.8)
plt.annotate(ICSE, (.02,.050), weight='bold', fontsize=10)
plt.annotate(ICSEM, (.02,.035), weight='regular', fontsize=9, alpha=.8)
plt.annotate(SkillsHeader, (.7,.8), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.44), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(Interests, (.7,.38), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(InterestsDesc, (.7,.28), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(CodeTitle, (.7,.2), weight='bold', fontsize=10, color='#ffffff')

#add qr code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg

from PIL import Image
arr_code = mpimg.imread(r"C:\Users\Lenovo\Downloads\QR code.png")
imagebox = OffsetImage(arr_code, zoom=0.28)
ab = AnnotationBbox(imagebox, (0.84, 0.10))
ax.add_artist(ab)
plt.savefig('myresume.png', dpi=300, bbox_inches='tight')
